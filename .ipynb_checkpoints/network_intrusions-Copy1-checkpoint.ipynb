# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import rcParams
import statsmodels.formula.api as SM
from matplotlib.pyplot import figure
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings("ignore")

# %%
ni_df=pd.read_csv('networkintrusion.csv')

# %%
ni_df.head()
# Out:
#    duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0         0           tcp   private   REJ        0.0        0.0     0
# 1         0           tcp   private   REJ        0.0        0.0     0
# 2         2           tcp  ftp_data    SF    12983.0        0.0     0
# 3         0          icmp     eco_i    SF       20.0        0.0     0
# 4         1           tcp    telnet  RSTO        0.0       15.0     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  10
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  86
# 3               0       0    0  ...                  57
# 4               0       0    0  ...                  86
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.04                    0.06
# 1                    0.00                    0.06
# 2                    0.61                    0.04
# 3                    1.00                    0.00
# 4                    0.31                    0.17
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.00                         0.00
# 1                         0.00                         0.00
# 2                         0.61                         0.02
# 3                         1.00                         0.28
# 4                         0.03                         0.02
#
#    dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                   0.0                       0.0                  1.00
# 1                   0.0                       0.0                  1.00
# 2                   0.0                       0.0                  0.00
# 3                   0.0                       0.0                  0.00
# 4                   0.0                       0.0                  0.83
#
#    dst_host_srv_rerror_rate    class
# 0                      1.00  anomaly
# 1                      1.00  anomaly
# 2                      0.00   normal
# 3                      0.00  anomaly
# 4                      0.71  anomaly
#
# [5 rows x 40 columns]

# %%
ni_df.tail()
# Out:
#        duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 22539         0           tcp      smtp   SF      794.0      333.0     0
# 22540         0           tcp      http   SF      317.0      938.0     0
# 22541         0           tcp      http   SF    54540.0     8314.0     0
# 22542         0           udp  domain_u   SF       42.0       42.0     0
# 22543         0           tcp    sunrpc  REJ        0.0        0.0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 22539               0       0    0  ...                 141
# 22540               0       0    0  ...                 255
# 22541               0       0    2  ...                 255
# 22542               0       0    0  ...                 252
# 22543               0       0    0  ...                  21
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 22539                    0.72                    0.06
# 22540                    1.00                    0.00
# 22541                    1.00                    0.00
# 22542                    0.99                    0.01
# 22543                    0.08                    0.03
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 22539                         0.01                         0.01
# 22540                         0.01                         0.01
# 22541                         0.00                         0.00
# 22542                         0.00                         0.00
# 22543                         0.00                         0.00
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 22539                  0.01                       0.0                  0.00
# 22540                  0.01                       0.0                  0.00
# 22541                  0.00                       0.0                  0.07
# 22542                  0.00                       0.0                  0.00
# 22543                  0.00                       0.0                  0.44
#
#        dst_host_srv_rerror_rate    class
# 22539                      0.00   normal
# 22540                      0.00   normal
# 22541                      0.07  anomaly
# 22542                      0.00   normal
# 22543                      1.00  anomaly
#
# [5 rows x 40 columns]

# %%
ni_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22544 entries, 0 to 22543
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   duration                     22544 non-null  int64
#  1   protocol_type                22544 non-null  object
#  2   service                      22544 non-null  object
#  3   flag                         22544 non-null  object
#  4   src_bytes                    22538 non-null  float64
#  5   dst_bytes                    22538 non-null  float64
#  6   land                         22544 non-null  int64
#  7   wrong_fragment               22544 non-null  int64
#  8   urgent                       22544 non-null  int64
#  9   hot                          22544 non-null  int64
#  10  num_failed_logins            22544 non-null  int64
#  11  logged_in                    22544 non-null  int64
#  12  num_compromised              22544 non-null  int64
#  13  root_shell                   22544 non-null  int64
#  14  num_root                     22544 non-null  int64
#  15  num_shells                   22544 non-null  int64
#  16  num_access_files             22544 non-null  int64
#  17  num_outbound_cmds            22544 non-null  int64
#  18  is_host_login                22544 non-null  int64
#  19  is_guest_login               22544 non-null  int64
#  20  count                        22535 non-null  float64
#  21  srv_count                    22535 non-null  float64
#  22  serror_rate                  22544 non-null  float64
#  23  srv_serror_rate              22544 non-null  float64
#  24  rerror_rate                  22544 non-null  float64
#  25  srv_rerror_rate              22544 non-null  float64
#  26  same_srv_rate                22544 non-null  float64
#  27  diff_srv_rate                22544 non-null  float64
#  28  srv_diff_host_rate           22544 non-null  float64
#  29  dst_host_count               22544 non-null  int64
#  30  dst_host_srv_count           22544 non-null  int64
#  31  dst_host_same_srv_rate       22544 non-null  float64
#  32  dst_host_diff_srv_rate       22544 non-null  float64
#  33  dst_host_same_src_port_rate  22544 non-null  float64
#  34  dst_host_srv_diff_host_rate  22544 non-null  float64
#  35  dst_host_serror_rate         22544 non-null  float64
#  36  dst_host_srv_serror_rate     22544 non-null  float64
#  37  dst_host_rerror_rate         22544 non-null  float64
#  38  dst_host_srv_rerror_rate     22544 non-null  float64
#  39  class                        22544 non-null  object
# dtypes: float64(19), int64(17), object(4)
# memory usage: 6.9+ MB

# %%
ni_df.describe().T
# Out:
#                                count          mean            std  min  \
# duration                     22544.0    218.859076    1407.176612  0.0
# src_bytes                    22538.0  10398.121706  472849.333214  0.0
# dst_bytes                    22538.0   2055.583770   21221.899178  0.0
# land                         22544.0      0.000311       0.017619  0.0
# wrong_fragment               22544.0      0.008428       0.142599  0.0
# urgent                       22544.0      0.000710       0.036473  0.0
# hot                          22544.0      0.105394       0.928428  0.0
# num_failed_logins            22544.0      0.021647       0.150328  0.0
# logged_in                    22544.0      0.442202       0.496659  0.0
# num_compromised              22544.0      0.119899       7.269597  0.0
# root_shell                   22544.0      0.002440       0.049334  0.0
# num_root                     22544.0      0.114665       8.041614  0.0
# num_shells                   22544.0      0.001153       0.048014  0.0
# num_access_files             22544.0      0.003549       0.067829  0.0
# num_outbound_cmds            22544.0      0.000000       0.000000  0.0
# is_host_login                22544.0      0.000488       0.022084  0.0
# is_guest_login               22544.0      0.028433       0.166211  0.0
# count                        22535.0     79.011360     128.522332  0.0
# srv_count                    22535.0     31.110095      89.021735  0.0
# serror_rate                  22544.0      0.102924       0.295367  0.0
# srv_serror_rate              22544.0      0.103635       0.298332  0.0
# rerror_rate                  22544.0      0.238463       0.416118  0.0
# srv_rerror_rate              22544.0      0.235179       0.416215  0.0
# same_srv_rate                22544.0      0.740345       0.412496  0.0
# diff_srv_rate                22544.0      0.094074       0.259138  0.0
# srv_diff_host_rate           22544.0      0.098110       0.253545  0.0
# dst_host_count               22544.0    193.869411      94.035663  0.0
# dst_host_srv_count           22544.0    140.750532     111.783972  0.0
# dst_host_same_srv_rate       22544.0      0.608722       0.435688  0.0
# dst_host_diff_srv_rate       22544.0      0.090540       0.220717  0.0
# dst_host_same_src_port_rate  22544.0      0.132261       0.306268  0.0
# dst_host_srv_diff_host_rate  22544.0      0.019638       0.085394  0.0
# dst_host_serror_rate         22544.0      0.097814       0.273139  0.0
# dst_host_srv_serror_rate     22544.0      0.099426       0.281866  0.0
# dst_host_rerror_rate         22544.0      0.233385       0.387229  0.0
# dst_host_srv_rerror_rate     22544.0      0.226683       0.400875  0.0
#
#                                 25%     50%       75%         max
# duration                       0.00    0.00    0.0000     57715.0
# src_bytes                      0.00   54.00  287.0000  62825648.0
# dst_bytes                      0.00   46.00  601.0000   1345927.0
# land                           0.00    0.00    0.0000         1.0
# wrong_fragment                 0.00    0.00    0.0000         3.0
# urgent                         0.00    0.00    0.0000         3.0
# hot                            0.00    0.00    0.0000       101.0
# num_failed_logins              0.00    0.00    0.0000         4.0
# logged_in                      0.00    0.00    1.0000         1.0
# num_compromised                0.00    0.00    0.0000       796.0
# root_shell                     0.00    0.00    0.0000         1.0
# num_root                       0.00    0.00    0.0000       878.0
# num_shells                     0.00    0.00    0.0000         5.0
# num_access_files               0.00    0.00    0.0000         4.0
# num_outbound_cmds              0.00    0.00    0.0000         0.0
# is_host_login                  0.00    0.00    0.0000         1.0
# is_guest_login                 0.00    0.00    0.0000         1.0
# count                          1.00    8.00  123.0000       511.0
# srv_count                      1.00    6.00   16.0000       511.0
# serror_rate                    0.00    0.00    0.0000         1.0
# srv_serror_rate                0.00    0.00    0.0000         1.0
# rerror_rate                    0.00    0.00    0.2500         1.0
# srv_rerror_rate                0.00    0.00    0.0725         1.0
# same_srv_rate                  0.25    1.00    1.0000         1.0
# diff_srv_rate                  0.00    0.00    0.0600         1.0
# srv_diff_host_rate             0.00    0.00    0.0000         1.0
# dst_host_count               121.00  255.00  255.0000       255.0
# dst_host_srv_count            15.00  168.00  255.0000       255.0
# dst_host_same_srv_rate         0.07    0.92    1.0000         1.0
# dst_host_diff_srv_rate         0.00    0.01    0.0600         1.0
# dst_host_same_src_port_rate    0.00    0.00    0.0300         1.0
# dst_host_srv_diff_host_rate    0.00    0.00    0.0100         1.0
# dst_host_serror_rate           0.00    0.00    0.0000         1.0
# dst_host_srv_serror_rate       0.00    0.00    0.0000         1.0
# dst_host_rerror_rate           0.00    0.00    0.3600         1.0
# dst_host_srv_rerror_rate       0.00    0.00    0.1700         1.0

# %% [markdown]
# ### Functions used in the program

# %% [markdown]
# #### Function for Outlier Treatment

# %%
def treat_outlier(col):
    sorted(col)
    Q1,Q3=np.percentile(col,[25,75])
    IQR=Q3-Q1
    lower_range= Q1-(1.5 * IQR)
    upper_range= Q3+(1.5 * IQR)
    return lower_range, upper_range

# %% [markdown]
# ### Plotting Decision Tree

# %%
def get_dt_graph(dt_classifier):
    fig = plt.figure(figsize=(25,20))
    _ = tree.plot_tree(dt_classifier,
                       feature_names=X.columns,
                       class_names=['N/w Intruded', "N/w not Intruded"],
                       filled=True)

# %% [markdown]
# ### Function to  find special chars & any repetitive data points which aren't duplicates

# %%
def find_specialchar(df):
    for feature in df.columns:
        print('The unique values in ' , feature , 'are as below')
        print('\n')
        print(df[feature].unique())
        print('\n')
    return

# %% [markdown]
# ### Function to check VIF for multicolinearity

# %%
def vif_cal(input_data):
    
    x_vars=input_data
    xvar_names=input_data.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=SM.ols(formula="y~x", data=x_vars).fit().rsquared  
        vif=round(1/(1-rsq),2)
        print (xvar_names[i], " VIF = " , vif)

# %% [markdown]
# # Basic Data Exploration
#
# **In this step, we will perform the below operations to check what the data set comprises of. We will check the below things:**
#
# - **shape of the dataset**
# - **info of the dataset**
# - **summary of the dataset**
# - **check for any Null Values**
# - **check for any Duplicate records**
# - **check for any special charecters**

# %%
ni_df.shape
# Out:
# (22544, 40)

# %%
ni_df.isnull().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      6
# dst_bytes                      6
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# num_root                       0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          9
# srv_count                      9
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# same_srv_rate                  0
# diff_srv_rate                  0
# srv_diff_host_rate             0
# dst_host_count                 0
# dst_host_srv_count             0
# dst_host_same_srv_rate         0
# dst_host_diff_srv_rate         0
# dst_host_same_src_port_rate    0
# dst_host_srv_diff_host_rate    0
# dst_host_serror_rate           0
# dst_host_srv_serror_rate       0
# dst_host_rerror_rate           0
# dst_host_srv_rerror_rate       0
# class                          0
# dtype: int64

# %% [markdown]
# ##### The following fields have missing values it is better  for us to have them dropped
# -  src_bytes 6
# -  dst_bytes 6
# -  count 9
# -  srv_count 9

# %%
# Check for duplicate data

dups = ni_df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))

ni_df[dups]
# Out:
# Number of duplicate rows = 3
#        duration protocol_type service flag  src_bytes  dst_bytes  land  \
# 10256         0           tcp   other  REJ        0.0        0.0     0
# 10619         0           tcp   other  REJ        0.0        0.0     0
# 15044         0           tcp   other  REJ        0.0        0.0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 10256               0       0    0  ...                   1
# 10619               0       0    0  ...                   1
# 15044               0       0    0  ...                   1
#
#        dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 10256                     0.0                     1.0
# 10619                     0.0                     1.0
# 15044                     0.0                     1.0
#
#        dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 10256                          0.0                          0.0
# 10619                          0.0                          0.0
# 15044                          0.0                          0.0
#
#        dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \
#
#     79   707  7277   247  7607  8113   781    32  7485    69 47114  7578
#   7470   815  7249  8039  9645  7440  7633   207  7336  7645  8015  8044
#   7312    89  7464  7967  7771   433  2091  7565  7583  7254  7322  8088
#   8197   703   208    43  8105  8148  7591  2100   373   239  7469  2873
#   7348  7538  7362  7246  4906  7570  7293  8189  8196   811  7650  7779
#   8036   192  8205  7582   988   163  7374    50  7577  7332  7599  7589
#   8133  7497   684  8141   469  7460   285  8117  7278  7257   171    25
#    942  7384  7273  7991  8129   112  8023  7597  8216  7477  7264  8209]
#
#
# The unique values in  protocol_type are as below
#
#
# ['tcp' 'icmp' 'udp']
#
#
# The unique values in  service are as below
#
#
# ['private' 'ftp_data' 'eco_i' 'telnet' 'http' 'smtp' 'ftp' 'ldap' 'pop_3'
#  'courier' 'discard' 'ecr_i' 'imap4' 'domain_u' 'mtp' 'systat' 'iso_tsap'
#  'other' 'csnet_ns' 'finger' 'uucp' 'whois' 'netbios_ns' 'link' 'Z39_50'
#  'sunrpc' 'auth' 'netbios_dgm' 'uucp_path' 'vmnet' 'domain' 'name' 'pop_2'
#  'http_443' 'urp_i' 'login' 'gopher' 'exec' 'time' 'remote_job' 'ssh'
#  'kshell' 'sql_net' 'shell' 'hostnames' 'echo' 'daytime' 'pm_dump' 'IRC'
#  'netstat' 'ctf' 'nntp' 'netbios_ssn' 'tim_i' 'supdup' 'bgp' 'nnsp' 'rje'
#  'printer' 'efs' 'X11' 'ntp_u' 'klogin' 'tftp_u']
#
#
# The unique values in  flag are as below
#
#
# ['REJ' 'SF' 'RSTO' 'S0' 'RSTR' 'SH' 'S3' 'S2' 'S1' 'RSTOS0' 'OTH']
#
#
# The unique values in  src_bytes are as below
#
#
# [0.000000e+00 1.298300e+04 2.000000e+01 ... 2.194619e+06 9.500000e+02
#  7.940000e+02]
#
#
# The unique values in  dst_bytes are as below
#
#
# [0.0000e+00 1.5000e+01 1.4515e+04 ... 1.6257e+04 1.4839e+04 6.0870e+03]
#
#
# The unique values in  land are as below
#
#
# [0 1]
#
#
# The unique values in  wrong_fragment are as below
#
#
# [0 1 3]
#
#
# The unique values in  urgent are as below
#
#
# [0 1 2 3]
#
#
# The unique values in  hot are as below
#
#
# [  0   4   2   1   7   6   5   3  22  10  11  19 101  18  15  30]
#
#
# The unique values in  num_failed_logins are as below
#
#
# [0 1 3 2 4]
#
#
# The unique values in  logged_in are as below
#
#
# [0 1]
#
#
# The unique values in  num_compromised are as below
#
#
# [  0   1 611   2   8  14 165  11  15  10   5  25  49   6 381   4 796   3
#    9  36  23  57   7]
#
#
# The unique values in  root_shell are as below
#
#
# [0 1]
#
#
# The unique values in  num_root are as below
#
#
# [  0   1 684   4  23 173  17   7   3   8   2 145  26 401 878  31   9  45
#   51   5]
#
#
# The unique values in  num_shells are as below
#
#
# [0 1 2 5]
#
#
# The unique values in  num_access_files are as below
#
#
# [0 1 3 2 4]
#
#
# The unique values in  num_outbound_cmds are as below
#
#
# [0]
#
#
# The unique values in  is_host_login are as below
#
#
# [0 1]
#
#
# The unique values in  same_srv_rate are as below
#
#
# [0.04 0.01 1.   0.02 0.09 0.16 0.07 0.05 0.08 0.   0.5  0.06 0.03 0.25
#  0.12 0.33 0.14 0.11 0.99 0.1  0.8  0.15 0.67 0.13 0.95 0.34 0.19 0.18
#  0.17 0.2  0.24 0.27 0.38 0.75 0.86 0.29 0.6  0.92 0.37 0.23 0.94 0.78
#  0.43 0.39 0.26 0.91 0.42 0.3  0.54 0.47 0.35 0.21 0.41 0.32 0.28 0.22
#  0.56 0.62 0.36 0.85 0.31 0.98 0.4  0.46 0.55 0.52 0.83 0.48 0.65 0.9
#  0.57 0.89 0.53 0.93 0.58]
#
#
# The unique values in  diff_srv_rate are as below
#
#
# [0.06 0.   0.07 0.05 0.38 1.   0.08 0.01 0.67 0.11 0.4  0.09 0.86 0.63
#  0.75 0.02 0.1  0.99 0.55 0.34 0.15 0.2  0.16 0.7  0.83 0.54 0.94 0.96
#  0.69 0.03 0.5  0.97 0.8  0.98 0.12 0.29 0.64 0.74 0.58 0.95 0.9  0.89
#  0.87 0.21 0.19 0.18 0.71 0.6  0.79 0.57 0.77 0.68 0.28 0.78 0.46 0.17
#  0.88 0.22 0.49 0.53 0.76 0.56 0.81 0.36 0.27 0.51 0.25 0.35 0.61 0.31
#  0.14 0.13 0.24 0.65 0.84 0.93 0.33 0.59 0.91 0.39 0.48 0.44 0.42 0.26
#  0.85 0.82 0.32 0.66 0.3  0.45 0.23 0.47 0.92 0.52 0.73 0.43 0.62 0.72
#  0.41]
#
#
# The unique values in  srv_diff_host_rate are as below
#
#
# [0.   1.   0.75 0.04 0.11 0.08 0.1  0.92 0.12 0.07 0.2  0.83 0.17 0.38
#  0.13 0.4  0.36 0.5  0.25 0.67 0.56 0.26 0.14 0.01 0.33 0.57 0.06 0.22
#  0.21 0.16 0.71 0.29 0.18 0.05 0.27 0.43 0.15 0.6  0.19 0.23 0.09 0.8
#  0.95 0.02 0.42 0.7  0.3  0.28 0.64 0.96 0.88 0.79 0.31 0.74 0.54 0.89
#  0.24 0.91 0.03 0.45 0.76 0.44 0.9  0.87 0.93 0.78 0.62 0.55 0.63 0.69
#  0.94 0.86 0.53 0.73 0.39 0.66 0.82 0.61 0.58 0.35 0.84 0.47 0.32 0.65]
#
#
# The unique values in  dst_host_count are as below
#
#
# [255 134   3  29 155 151  52 235  38  71  35  36 180  46 241 158  20 185
#   53 203  13  91  21   9   7 106  61  10  85  40  81   1   4  69 189  14
#  110  96  30  62 248  26  25  80  74 171 220 105 131 186  11   2 160 206
#   90 166  72  67 149 100  64 218 192 254  32  47  58   8  33 193 146 222
#   22  18 138 179 133 244 238  51 148 181 118   5 233  50 101   6 142 152
#  226 141 157 104 120  87  94 111 188  84  48  34 128  43 168  45  41  65
#   76 150  19  63 237 253  82  49 196 143 162  24 223 212 177 163 126 200
#   16  79 115 169 103  28 211 199 187 119 140 172  37 129 107 225 224  42
#  216  15 210 175  78 113 214 117  55  95  93 190 230 217  56  86 173 198
#  167 170  97 215 161  70 249 132 239 219  31  23 213 182 194  60  59 114
#  0.9  0.39 0.59 0.78 0.61 0.42 0.6  0.81 0.97 0.26 0.51 0.46 0.47 0.54
#  0.23 0.34 0.37]
#
#
# The unique values in  dst_host_same_src_port_rate are as below
#
#
# [0.   0.61 1.   0.03 0.01 0.02 0.83 0.05 0.99 0.38 0.08 0.26 0.33 0.11
#  0.86 0.1  0.14 0.25 0.19 0.07 0.04 0.75 0.09 0.93 0.78 0.88 0.85 0.06
#  0.23 0.64 0.82 0.98 0.2  0.96 0.17 0.91 0.51 0.57 0.31 0.95 0.27 0.45
#  0.81 0.5  0.97 0.24 0.87 0.3  0.22 0.12 0.47 0.89 0.7  0.72 0.67 0.13
#  0.52 0.76 0.15 0.46 0.18 0.35 0.63 0.16 0.92 0.34 0.21 0.94 0.84 0.32
#  0.29 0.28 0.8  0.9  0.66 0.4  0.43 0.55 0.77 0.42 0.79 0.53 0.44 0.74
#  0.65 0.36 0.71 0.6  0.62 0.37 0.54 0.58 0.69 0.49 0.39 0.73 0.59 0.41
#  0.68 0.48 0.56]
#
#
# The unique values in  dst_host_srv_diff_host_rate are as below
#
#
# [0.   0.02 0.28 0.03 0.04 0.05 0.01 0.14 0.2  0.52 0.08 0.06 0.5  0.51
#  1.   0.33 0.13 0.07 0.38 0.25 0.09 0.4  0.29 0.12 0.17 0.1  0.26 0.57
#  0.54 0.21 0.48 0.3  0.24 0.11 0.16 0.18 0.23 0.53 0.19 0.31 0.15 0.27
#  0.22 0.32 0.43 0.6  0.36 0.62 0.56 0.46 0.8  0.55 0.67 0.42 0.75 0.41
#  0.47 0.39]
#
#
# The unique values in  dst_host_serror_rate are as below
#
#
# [0.   0.01 0.69 1.   0.05 0.03 0.33 0.1  0.02 0.53 0.5  0.99 0.04 0.27
#  0.39 0.38 0.65 0.44 0.14 0.12 0.06 0.4  0.45 0.21 0.49 0.17 0.55 0.83
#  0.13 0.61 0.09 0.72 0.37 0.3  0.67 0.11 0.34 0.18 0.31 0.87 0.46 0.2
#  0.97 0.75 0.15 0.78 0.24 0.25 0.71 0.8  0.19 0.86 0.16 0.98 0.07 0.56
#  0.58 0.48 0.81 0.41 0.51 0.29 0.23 0.77 0.74 0.52 0.64 0.08 0.22 0.73
#  0.82 0.35 0.54 0.96 0.32 0.42 0.7  0.79 0.62 0.63 0.47 0.95 0.6  0.36
#  0.94 0.89 0.92 0.28 0.57 0.76 0.59 0.91 0.66 0.43 0.84 0.68 0.26 0.85
#  0.88]
#
#
# The unique values in  dst_host_srv_serror_rate are as below
#
#
# [0.   0.01 0.95 0.77 1.   0.39 0.02 0.37 0.75 0.66 0.38 0.65 0.8  0.05
#  0.14 0.06 0.58 0.22 0.78 0.44 0.36 0.51 0.97 0.23 0.43 0.55 0.76 0.1
#  0.72 0.82 0.67 0.34 0.03 0.56 0.28 0.79 0.29 0.98 0.84 0.4  0.47 0.41
#  0.83 0.21 0.04 0.25 0.08 0.5  0.87 0.73 0.46 0.11 0.81 0.18 0.74 0.71
#  0.16 0.93 0.2  0.45 0.52 0.49 0.07 0.48 0.62 0.69 0.64 0.42 0.3  0.59
#  0.96 0.68 0.57 0.35 0.91 0.7  0.63 0.31 0.6  0.15 0.54 0.33 0.9  0.61
#  0.27 0.92 0.09 0.86 0.99 0.12 0.88 0.32 0.53 0.13 0.17 0.19 0.89 0.94
#  0.85 0.26 0.24]
#
#
# The unique values in  dst_host_rerror_rate are as below
#
#
# [1.   0.   0.83 0.72 0.02 0.66 0.33 0.07 0.01 0.96 0.89 0.06 0.44 0.12
#  0.91 0.11 0.99 0.88 0.23 0.98 0.31 0.9  0.17 0.24 0.19 0.8  0.2  0.97
#  0.04 0.32 0.4  0.47 0.22 0.68 0.16 0.65 0.7  0.13 0.77 0.73 0.67 0.34
#  0.94 0.56 0.43 0.35 0.09 0.05 0.14 0.84 0.87 0.03 0.1  0.6  0.25 0.95
#  0.38 0.82 0.62 0.63 0.51 0.81 0.49 0.3  0.61 0.79 0.69 0.41 0.85 0.42
#  0.76 0.08 0.71 0.36 0.53 0.74 0.78 0.39 0.57 0.18 0.92 0.45 0.29 0.86
#  0.5  0.64 0.55 0.26 0.58 0.37 0.27 0.48 0.93 0.52 0.46 0.15 0.21 0.59
#  0.75 0.28 0.54]
#
#
# The unique values in  dst_host_srv_rerror_rate are as below
#
#
# [1.   0.   0.71 0.04 0.02 0.32 0.07 0.95 0.06 0.67 0.01 0.19 0.98 0.22
#  0.18 0.03 0.7  0.49 0.68 0.16 0.31 0.43 0.97 0.59 0.51 0.05 0.08 0.77
#  0.75 0.69 0.48 0.37 0.17 0.35 0.96 0.23 0.53 0.25 0.3  0.27 0.65 0.66
#  0.44 0.56 0.41 0.12 0.62 0.14 0.2  0.6  0.72 0.36 0.54 0.4  0.1  0.94
#  0.84 0.15 0.82 0.91 0.13 0.64 0.46 0.73 0.58 0.88 0.63 0.11 0.47 0.89
#  0.8  0.93 0.09 0.5  0.33 0.61 0.24 0.81 0.74 0.28 0.39 0.57 0.9  0.42
#  0.29 0.34 0.26 0.86 0.55 0.83 0.92 0.38 0.21 0.76 0.87 0.52 0.45 0.78
#  0.85 0.79]
#
#
# The unique values in  class are as below
#
#
# ['anomaly' 'normal']

# %% [markdown]
# #### The following fields are of categorical
# - protocol_type,service,flag,land,wrong_fragment,urgent,
# - hot,num_failed_logins,logged_in,num_compromised,root_shell,
# - num_root,num_access_files,is_host_login,is_guest_login,count,
# - srv_count,rerror_rate,srv_rerror_rate,same_srv_rate,diff_srv_rate
# - srv_diff_host_rate,dst_host_count,dst_host_srv_count,dst_host_same_srv_rate
# - dst_host_diff_srv_rate,dst_host_same_src_port_rate,dst_host_srv_diff_host_rate
# - dst_host_serror_rate,dst_host_rerror_rate,dst_host_srv_rerror_rate,class,duration
#
# ##### Contineous fields are the below
# - src_bytes
# - dst_bytes
#
# ##### num_outbound_cmds -only 0 so this could be dropped

# %%
ni_df['class'].value_counts()
# Out:
# anomaly    12830
# normal      9711
# Name: class, dtype: int64

# %%
ni_df['class'].value_counts().plot(kind='bar',color=['teal','brown']);

# %%
rcParams['figure.figsize'] = 15, 15
ni_df.hist();
